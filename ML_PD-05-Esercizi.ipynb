# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Indovina-il-numero" data-toc-modified-id="Indovina-il-numero-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Indovina il numero</a></span></li><li><span><a href="#Impariamo-le-tabelline" data-toc-modified-id="Impariamo-le-tabelline-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Impariamo le tabelline</a></span><ul class="toc-item"><li><span><a href="#Ottimizzazione" data-toc-modified-id="Ottimizzazione-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Ottimizzazione</a></span></li><li><span><a href="#Livelli-di-difficolta'" data-toc-modified-id="Livelli-di-difficolta'-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Livelli di difficolta'</a></span></li><li><span><a href="#Variazioni-sul-tema" data-toc-modified-id="Variazioni-sul-tema-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Variazioni sul tema</a></span></li></ul></li><li><span><a href="#Sulle-Liste,-Tuple-e-Stringhe:" data-toc-modified-id="Sulle-Liste,-Tuple-e-Stringhe:-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Sulle Liste, Tuple e Stringhe:</a></span><ul class="toc-item"><li><span><a href="#Scrivere-uno-script-che-crea-una-lista-di-100-elementi-randomici-tra--5000-e-+5000,-utilizzando-l'operatore-&quot;+&quot;-che-aggiunge-un-elemento-in-coda-alla-lista-all'interno-di-un-ciclo-for" data-toc-modified-id="Scrivere-uno-script-che-crea-una-lista-di-100-elementi-randomici-tra--5000-e-+5000,-utilizzando-l'operatore-&quot;+&quot;-che-aggiunge-un-elemento-in-coda-alla-lista-all'interno-di-un-ciclo-for-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Scrivere uno script che crea una lista di 100 elementi randomici tra -5000 e +5000, utilizzando l'operatore "+" che aggiunge un elemento in coda alla lista all'interno di un ciclo for</a></span></li><li><span><a href="#Stampare-a-video-la-lista-in-ordine-crescente-e-decrescente:" data-toc-modified-id="Stampare-a-video-la-lista-in-ordine-crescente-e-decrescente:-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Stampare a video la lista in ordine crescente e decrescente:</a></span></li><li><span><a href="#Stampare-a-video-i-primi-10-elementi-e-gli-ultimi-10-elementi-della-lista:" data-toc-modified-id="Stampare-a-video-i-primi-10-elementi-e-gli-ultimi-10-elementi-della-lista:-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Stampare a video i primi 10 elementi e gli ultimi 10 elementi della lista:</a></span></li><li><span><a href="#Conteggio-degli-elementi-in-una-lista" data-toc-modified-id="Conteggio-degli-elementi-in-una-lista-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Conteggio degli elementi in una lista</a></span></li><li><span><a href="#Calcola-la-media-di-una-lista-di-interi-generata-casualmente" data-toc-modified-id="Calcola-la-media-di-una-lista-di-interi-generata-casualmente-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Calcola la media di una lista di interi generata casualmente</a></span></li><li><span><a href="#Randomizzare-gli-elemnti-di-una-lista" data-toc-modified-id="Randomizzare-gli-elemnti-di-una-lista-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Randomizzare gli elemnti di una lista</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Esercizi proposti
# Risovere gli esercizi che seguono, strutturando opportunamente il codice in funzioni.

# %% [markdown]
# ## Indovina il numero
# ```
# Scrivi uno script che ci permetta di giocare una partita a "Indovina il numero"
# Lo script deve pescare un numero casuale tra 1 e 1000 senza rivelarlo all'utente e chiedere al
# giocatore di indovinare il numero con il minor numeor di mosse possibili.
# Il giocatore inserisce il suo primo tentativo e se il numero e' troppo grande verra' visualizzato un
# messaggio "Troppo grande, riprova!" o se troppo piccolo "Troppo piccolo. Riprova!"
# QUando il numero viene indovinato verra' visualizzato il messaggio "Bravo hai indovinato in X mosse".
# Chiedere all'utente se vuole fare un'altra partita.
# ```

# %%
import random

numero_casuale = random.randint(1,1000)

# assegno a tentativo un intero inerito a video dall'utente:
tentativo = int(input("Prova ad indovinare un numero: "))
# Out:
# Prova ad indovinare un numero56

# %% [markdown]
# ## Impariamo le tabelline
# ```
# Scrivi una funzione che proponga ad un bambino una coppia di numeri interi compresi tra 1 e 10 e
# chieda di inserire il risultaato della motiplicazione, e dica infine se il risultato e' corretto o no:
#
# "Quanto fa 7 x 9 ?"
# 45
# "NO! Riprova"
# 63
# "E' corretto"
#
# "Quanto fa 5 x 5 ?"
# 25
# "Bravo, hai indovinato al primo tentativo!"
# ```

# %% [markdown]
# ### Ottimizzazione
# ```
# Modifica il precedente esercizio cercando di far variare le risposte del computer:
# "Ottimo lavoro", "Molto bene" o "Bravissimo" quando si indovina il risultato.
# "No, Riprova", "Sbagliato, prova di nuovo", "No, ancora un tentativo", se si risonde in modo scorretto.
# Pesca un numero da uno a tre e usa una delle tre modalita' per dare il corretto feedback allo studente.
# ```

# %% [markdown]
# ### Livelli di difficolta'
# ```
# Modifica gli script realizzati in precedenza per aggiungere un livello di difficolta' alle operazioni:
# Livello 1: operazioni a 1 cifra (3 x 4, 6 x 7).
# Livello 2: operazioni a 2 cifre (18 x 34).
# ```

# %% [markdown]
# ### Variazioni sul tema
# ```
# Modifica il lavoro svolto in precedenza affinche' l'esercizio possa essere svolto scegliendo volta per volta
# tra le 4 operazioni:
# 1: Somma
# 2: Sottrazione
# 3: Prodotto
# 4: Divisione (impedendo la divisione per zero)
# 5: Operazione casuale
# ```

# %% [markdown]
# ## Sulle Liste, Tuple e Stringhe:

# %% [markdown]
# ### Scrivere uno script che crea una lista di 100 elementi randomici tra -5000 e +5000, utilizzando l'operatore "+" che aggiunge un elemento in coda alla lista all'interno di un ciclo for

# %%
import random

# creo una lista vuota
mia_lista_1 = []

# anche con il costruttore list()
# mia_lista_2 = list()

# %%
# for j in range(100):
#     mia_lista_1 += [random.randint(-5000,5000)]

# %%
# tipicamente quando costruisco una lista in questo modo si preferisce utilizzare la funzione
# append()

for j in range(random.randint(1,5000)):
    mia_lista_1.append(random.randint(-5000,5000))

# %% [markdown]
# ### Stampare a video la lista in ordine crescente e decrescente:

# %%
print(sorted(mia_lista_1))
# Out:
# [-5000, -4999, -4998, -4994, -4992, -4992, -4991, -4987, -4986, -4985, -4984, -4983, -4982, -4981, -4980, -4978, -4978, -4977, -4974, -4973, -4973, -4970, -4969, -4967, -4967, -4964, -4963, -4963, -4962, -4960, -4959, -4955, -4955, -4955, -4950, -4947, -4947, -4942, -4942, -4941, -4941, -4937, -4937, -4933, -4933, -4933, -4930, -4929, -4926, -4923, -4920, -4919, -4919, -4917, -4913, -4910, -4909, -4907, -4905, -4903, -4902, -4899, -4899, -4898, -4897, -4895, -4893, -4890, -4888, -4886, -4885, -4884, -4881, -4878, -4877, -4877, -4869, -4869, -4865, -4861, -4860, -4859, -4856, -4853, -4848, -4847, -4846, -4844, -4843, -4842, -4842, -4838, -4838, -4833, -4832, -4826, -4824, -4823, -4820, -4817, -4817, -4815, -4814, -4814, -4813, -4809, -4809, -4808, -4807, -4804, -4803, -4801, -4800, -4798, -4795, -4792, -4792, -4787, -4780, -4776, -4774, -4773, -4767, -4766, -4763, -4757, -4757, -4754, -4752, -4751, -4750, -4743, -4743, -4741, -4739, -4738, -4734, -4734, -4728, -4726, -4723, -4723, -47
# ...

# %%
print(sorted(mia_lista_1, reverse = True))
# Out:
# [4709, 4536, 4385, 4373, 4319, 4110, 4082, 4070, 3766, 3734, 3601, 3552, 3359, 3160, 3032, 3012, 2883, 2871, 2808, 2673, 2554, 2541, 2528, 2433, 2379, 2293, 2277, 2218, 2210, 2165, 2102, 1528, 1015, 931, 794, 777, 690, 684, 385, 157, 112, -199, -383, -387, -519, -554, -599, -605, -691, -715, -740, -773, -848, -872, -953, -971, -1037, -1056, -1061, -1082, -1200, -1227, -1253, -1564, -1565, -1674, -1901, -1989, -2001, -2023, -2059, -2084, -2265, -2374, -2485, -2544, -2685, -2874, -3102, -3104, -3189, -3284, -3379, -3517, -3529, -3613, -3655, -3659, -3691, -3793, -3859, -4006, -4068, -4253, -4305, -4380, -4558, -4626, -4792, -4877]

# %% [markdown]
# ### Stampare a video i primi 10 elementi e gli ultimi 10 elementi della lista:

# %%
print(mia_lista_1[0:10])

print(mia_lista_1[-10:])
# Out:
# [2541, -599, -4068, -4792, 4110, 2528, -2685, -953, -3284, 4709]
# [690, -2374, -1056, -1901, 2673, -2544, -1082, 2808, -4006, -1674]

# %% [markdown]
# ### Conteggio degli elementi in una lista

# %%
# si fa con len()

len(mia_lista_1)
# Out:
# 4611

# %% [markdown]
# ### Calcola la media di una lista di interi generata casualmente

# %%
sum(mia_lista_1)
# Out:
# -437158

# %%
media = sum(mia_lista_1) / len(mia_lista_1)

# %%
media
# Out:
# -94.80763391888961

# %% [markdown]
# ### Randomizzare gli elemnti di una lista

# %%
lista_da_1_a_100 = []

for j in range(1,101):
    lista_da_1_a_100.append(j)

# %%
copia = lista_da_1_a_100.copy()

# %%
random.shuffle(lista_da_1_a_100)
